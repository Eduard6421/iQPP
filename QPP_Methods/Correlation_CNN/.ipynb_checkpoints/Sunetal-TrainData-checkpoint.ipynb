# %%
import pandas as pd
import pickle
import torch
from torch.utils.data import DataLoader, Dataset,DataLoader,random_split
from sklearn.model_selection import KFold
from torch.optim import Adam
import torch.nn as nn
import numpy as np
from numpy import dot
from numpy.linalg import norm
import re

# %%
# -------------------------------------------------------- Global settings --------------------------------------------------------------
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Currently running on {device}".format())

BATCH_SIZE = 32
NUM_EPOCHS = 100
# Out:
# Currently running on cuda

# %%
def cosine_similarity(x,y):
    return dot(x,y) / (norm(x) * norm(y))
def parse_input(content): 
    regex = r"\[([0-9\s,\-\.e]+)\]"
    items = re.findall(regex, content)
    parsed_input = np.array([np.fromstring(embed, sep=',') for embed in items]).astype(float)
    return parsed_input

# %%
test_top_100_emb = '/notebooks/Embeddings/CNN_Image_Retrieval/caltech101_700-top-100-results-and-scores.csv'
test_scores_path = '/notebooks/Results/cnnimageretrieval-caltech101_700-p@100.csv'

train_top_100_emb = '/notebooks/Embeddings/CNN_Image_Retrieval/caltech101_700_train-top-100-results-and-scores.csv'
train_scores_path = '/notebooks/Results/cnnimageretrieval-caltech101_700_train-p@100.csv'

# %%
test_scores_df = pd.read_csv(test_scores_path)
train_scores_df = pd.read_csv(train_scores_path)

# %%
test_embeddings_df = pd.read_csv(test_top_100_emb)
train_embeddings_df = pd.read_csv(train_top_100_emb)

# %%
train_scores_df.shape
# Out:
# (700, 2)

# %%
test_inputs = []
for query_idx in range(len(test_embeddings_df)):
    if(query_idx % 50 == 0):
        print(query_idx)
    image_embeddings = test_embeddings_df['result_emb'].iloc[query_idx]
    image_embeddings = image_embeddings[1:-1]
    image_embeddings = parse_input(image_embeddings)
    test_inputs.append(image_embeddings)
test_inputs = np.array(test_inputs)
# Out:
# 0
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650

# %%
train_inputs = []
for query_idx in range(len(train_embeddings_df)):
    if(query_idx % 50 == 0):
        print(query_idx)
    image_embeddings = train_embeddings_df['result_emb'].iloc[query_idx]
    image_embeddings = image_embeddings[1:-1]
    image_embeddings = parse_input(image_embeddings)
    train_inputs.append(image_embeddings)    
train_inputs = np.array(train_inputs)
# Out:
# 0
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650

# %%
test_scores = test_scores_df['score'].to_numpy()
train_scores = train_scores_df['score'].to_numpy()

# %%
test_input_maps = []
for query_idx in range(len(test_inputs)):
    result_elements = test_inputs[query_idx,:,:]
    similarity_matrix = np.zeros((100,100))
    for i in range(100):
        for j in range(i, 100):
            similarity_matrix[i][j] = similarity_matrix[j][i] = cosine_similarity(result_elements[i],result_elements[j])
    new_similarity_matrix = np.zeros((50,50))
    
    test_input_maps.append(similarity_matrix)
test_input_maps = np.array(test_input_maps)
test_input_maps = test_input_maps.reshape(len(test_inputs),1,100,100)

# %%
test_paths = test_scores_df[['path']].to_numpy().squeeze(1)
test_dataset = np.array(list(zip(test_input_maps,test_scores, test_paths)))
# Out:
# /tmp/ipykernel_816/699035013.py:2: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   test_dataset = np.array(list(zip(test_input_maps,test_scores, test_paths)))

# %%
train_input_maps = []
for query_idx in range(len(train_inputs)):
    result_elements = train_inputs[query_idx,:,:]
    similarity_matrix = np.zeros((100,100))
    for i in range(100):
        for j in range(i, 100):
            similarity_matrix[i][j] = similarity_matrix[j][i] = cosine_similarity(result_elements[i],result_elements[j])
    new_similarity_matrix = np.zeros((50,50))
    
    train_input_maps.append(similarity_matrix)
train_input_maps = np.array(train_input_maps)
train_input_maps = train_input_maps.reshape(len(train_inputs),1,100,100)

# %%
train_paths = train_scores_df[['path']].to_numpy().squeeze(1)
train_dataset = np.array(list(zip(train_input_maps,train_scores, train_paths)))
# Out:
# /tmp/ipykernel_816/3498062631.py:2: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   train_dataset = np.array(list(zip(train_input_maps,train_scores, train_paths)))

# %%
class DifficultyDataset(Dataset):

    def __init__(self, data):
        self.correlation_matrices = data[:,0].tolist()
        self.scores = data[:,1]
        self.paths  = data[:,2].tolist()
    def __len__(self):
        return len(self.scores)

    def __getitem__(self, idx):

        matrix = torch.tensor(self.correlation_matrices[idx])
        score = torch.tensor(float(self.scores[idx]))
        query_path = self.paths[idx]

        return (matrix, score, query_path)

# %%
def compute_loss(model , loader):
    
    total_loss = 0.0
    
    with torch.no_grad():
        for data in loader:
            images, scores, paths = data
            
            images = images.to(device,dtype=torch.float)
            scores = scores.to(device).unsqueeze(1)
            
            outputs = model(images)
            
            loss = criterion(outputs, scores)
            total_loss += loss.item()
    
    total_loss /= len(loader)
    
    return total_loss

# %%
def train_model(model, train_dataloader, validation_dataloader, optimizer , criterion):
    
    min_loss = 1000
    
    for i in range(NUM_EPOCHS):
        print("Epoch num {}/{}".format(i+1,NUM_EPOCHS))
        
        epoch_train_loss = 0
        
        for idx, data in enumerate(train_dataloader):
            #print("Batch num {}/{}".format(idx+1, len(train_dataloader)))
 
            (images,scores,img_paths) = data
    
            images = images.to(device,dtype=torch.float)
            scores = scores.to(device).unsqueeze(1)
            
            optimizer.zero_grad()
            
            outputs = model(images)
            loss = criterion(scores, outputs)

            loss.backward()
            optimizer.step()
            
            epoch_train_loss += loss.item()
            
        epoch_train_loss /= len(train_dataloader)
        
        epoch_validation_loss = compute_loss(model, validation_dataloader)

        print("Epoch train loss {}".format(epoch_train_loss))
        print("Epoch validation loss {}".format(epoch_validation_loss))

# %%
class CNN_Network(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(1, 20 , 3, stride = 1)
        self.conv2 = nn.Conv2d(20, 50 , 3, stride = 1)
        self.conv3 = nn.Conv2d(50, 50 , 3, stride = 1)
        self.fc1   = nn.Linear(5000, 256)
        self.fc2   = nn.Linear(256, 1)
        
        self.max_pool   = nn.MaxPool2d(2)
        self.leaky_relu = nn.LeakyReLU(0.1)
        
    def forward(self, x):
        
        x = self.conv1(x)
        x = self.max_pool(x)
        x = self.leaky_relu(x)
        
        x = self.conv2(x)
        x = self.max_pool(x)
        x = self.leaky_relu(x)        
        
        x = self.conv3(x)
        x = self.max_pool(x)
        x = self.leaky_relu(x)
        
        x = x.reshape(-1,5000)
        x = self.fc1(x)
        x = self.leaky_relu(x)
        
        x = self.fc2(x)
        
        return x

# %%
train_dataset = np.array(train_dataset)
test_dataset = np.array(test_dataset)

# %%
score_dict = {}
train_diff_dataset = DifficultyDataset(train_dataset)
test_diff_dataset  = DifficultyDataset(test_dataset)

total_size = len(train_diff_dataset)
train_size = int(0.8 * total_size)
validation_size = total_size - train_size

train_data, validation_data = torch.utils.data.random_split(train_diff_dataset, [train_size, validation_size])
    
train_dataloader = DataLoader(train_data, batch_size=BATCH_SIZE, shuffle=True)
validation_dataloader = DataLoader(validation_data, batch_size=BATCH_SIZE, shuffle=True)
test_dataloader = DataLoader(test_diff_dataset, batch_size=BATCH_SIZE, shuffle=False)   
    
    
cnn_model = CNN_Network()
cnn_model = cnn_model.to(device)  
cnn_model.train()
    
criterion = torch.nn.MSELoss()
optimizer = Adam(cnn_model.parameters(), lr=0.0001)
train_model(cnn_model, train_dataloader, validation_dataloader , optimizer, criterion)
cnn_model.eval()
for item in test_dataset:
    image, score, path = item
    score = cnn_model(torch.tensor(image).unsqueeze(0).to(device,dtype=torch.float))
    score_dict[path] = score
# Out:
# Epoch num 1/100
# Epoch train loss 0.07684693651066886
# Epoch validation loss 0.07407002598047256
# Epoch num 2/100
# Epoch train loss 0.055412477917141385
# Epoch validation loss 0.06468752771615982
# Epoch num 3/100
# Epoch train loss 0.05506277187830872
# Epoch validation loss 0.06873870342969894
# Epoch num 4/100
# Epoch train loss 0.05326892497638861
# Epoch validation loss 0.06003846228122711
# Epoch num 5/100
# Epoch train loss 0.05186734638280339
# Epoch validation loss 0.06150553375482559
# Epoch num 6/100
# Epoch train loss 0.0505509153008461
# Epoch validation loss 0.06928308531641961
# Epoch num 7/100
# Epoch train loss 0.046177529729902744
# Epoch validation loss 0.06871036738157273
# Epoch num 8/100
# Epoch train loss 0.04974000290450123
# Epoch validation loss 0.05273613035678863
# Epoch num 9/100
# Epoch train loss 0.05091850252615081
# Epoch validation loss 0.057507140934467314
# Epoch num 10/100
# Epoch train loss 0.0473256078031328
# Epoch validation loss 0.05759362280368805
# Epoch num 11/100
# Epoch train loss 0.04361723301311334
# Epoch validation loss 0.05291202366352081
# Epoch num 12/100
# Epoch train loss 0.04254259251885944
# Epoch validation loss 0.05784430876374245
# Epoch num 13/100
# Epoch train loss 0.04237798342688216
# Epoch validation loss 0.04922501221299171
# Epoch num 14/100
# Epoch train loss 0.040156236125363245
# Epoch validation loss 0.049171270430088045
# Epoch num 15/100
# Epoch train loss 0.04052840452641249
# Epoch validation loss 0.053434469550848004
# Epoch num 16/100
# Epoch train loss 0.039632203264368907
# Epoch validation loss 0.057074780017137526
# Epoch num 17/100
# Epoch train loss 0.040157450570000544
# Epoch validation loss 0.0545057401061058
# Epoch num 18/100
# Epoch train loss 0.037577154114842415
# Epoch validation loss 0.04736300408840179
# Epoch num 19/100
# Epoch train loss 0.03788656089454889
# Epoch validation loss 0.052817818522453305
# Epoch num 20/100
# Epoch train loss 0.03711867311762439
# Epoch validation loss 0.04685044959187508
# Epoch num 21/100
# Epoch train loss 0.03852848781065808
# Epoch validation loss 0.048109240084886554
# Epoch num 22/100
# Epoch train loss 0.035651633619434304
# Epoch validation loss 0.05250775218009949
# Epoch num 23/100
# Epoch train loss 0.03695517136818833
# Epoch validation loss 0.04383023306727409
# Epoch num 24/100
# Epoch train loss 0.036241092512177095
# Epoch validation loss 0.04703326001763344
# Epoch num 25/100
# Epoch train loss 0.03568289221988784
# Epoch validation loss 0.04927229061722756
# Epoch num 26/100
# Epoch train loss 0.03508644954611858
# Epoch validation loss 0.04400739967823029
# Epoch num 27/100
# Epoch train loss 0.03377065228091346
# Epoch validation loss 0.05073930025100708
# Epoch num 28/100
# Epoch train loss 0.03366865393602186
# Epoch validation loss 0.042154837399721146
# Epoch num 29/100
# Epoch train loss 0.03441678453236818
# Epoch validation loss 0.0446358323097229
# Epoch num 30/100
# Epoch train loss 0.033942907945149474
# Epoch validation loss 0.04355567023158073
# Epoch num 31/100
# Epoch train loss 0.03460832799060477
# Epoch validation loss 0.04582282155752182
# Epoch num 32/100
# Epoch train loss 0.034414545736379094
# Epoch validation loss 0.04421360269188881
# Epoch num 33/100
# Epoch train loss 0.032929602079093456
# Epoch validation loss 0.04353608749806881
# Epoch num 34/100
# Epoch train loss 0.03244462614465091
# Epoch validation loss 0.043676911294460295
# Epoch num 35/100
# Epoch train loss 0.03306931733257241
# Epoch validation loss 0.04013701118528843
# Epoch num 36/100
# Epoch train loss 0.032149312655544944
# Epoch validation loss 0.04446166045963764
# Epoch num 37/100
# Epoch train loss 0.031966735143214464
# Epoch validation loss 0.04163219630718231
# Epoch num 38/100
# Epoch train loss 0.03241228798611297
# Epoch validation loss 0.041067925095558164
# Epoch num 39/100
# Epoch train loss 0.032464910143365465
# Epoch validation loss 0.04419351741671562
# Epoch num 40/100
# Epoch train loss 0.032398485475116305
# Epoch validation loss 0.04205385930836201
# Epoch num 41/100
# Epoch train loss 0.031686315312981606
# Epoch validation loss 0.041561837494373324
# Epoch num 42/100
# Epoch train loss 0.0322218949182166
# Epoch validation loss 0.039065086469054225
# Epoch num 43/100
# Epoch train loss 0.03379159565601084
# Epoch validation loss 0.041488272696733476
# Epoch num 44/100
# Epoch train loss 0.03112638286418385
# Epoch validation loss 0.04224509671330452
# Epoch num 45/100
# Epoch train loss 0.02997573609981272
# Epoch validation loss 0.04001938290894032
# Epoch num 46/100
# Epoch train loss 0.03131070246713029
# Epoch validation loss 0.04026074707508087
# Epoch num 47/100
# Epoch train loss 0.03171451503617896
# Epoch validation loss 0.04122513495385647
# Epoch num 48/100
# Epoch train loss 0.032623893581330776
# Epoch validation loss 0.04435455650091171
# Epoch num 49/100
# Epoch train loss 0.03013325534347031
# Epoch validation loss 0.040508948639035224
# Epoch num 50/100
# Epoch train loss 0.02975283045735624
# Epoch validation loss 0.04230722039937973
# Epoch num 51/100
# Epoch train loss 0.03144164300627179
# Epoch validation loss 0.04265179485082626
# Epoch num 52/100
# Epoch train loss 0.03146441373974085
# Epoch validation loss 0.041243630647659305
# Epoch num 53/100
# Epoch train loss 0.029651850875880983
# Epoch validation loss 0.045008882880210876
# Epoch num 54/100
# Epoch train loss 0.030328577073911827
# Epoch validation loss 0.043804679065942764
# Epoch num 55/100
# Epoch train loss 0.02875734291349848
# Epoch validation loss 0.04300380125641823
# Epoch num 56/100
# Epoch train loss 0.028490008268919256
# Epoch validation loss 0.0429993987083435
# Epoch num 57/100
# Epoch train loss 0.030297926264918514
# Epoch validation loss 0.038456710800528524
# Epoch num 58/100
# Epoch train loss 0.02895957205651535
# Epoch validation loss 0.04438228271901608
# Epoch num 59/100
# Epoch train loss 0.029591844003233645
# Epoch validation loss 0.040714485570788383
# Epoch num 60/100
# Epoch train loss 0.02742468886491325
# Epoch validation loss 0.04485733360052109
# Epoch num 61/100
# Epoch train loss 0.027853022536469832
# Epoch validation loss 0.04581943675875664
# Epoch num 62/100
# Epoch train loss 0.028153733246856265
# Epoch validation loss 0.0397739589214325
# Epoch num 63/100
# Epoch train loss 0.027209906735354
# Epoch validation loss 0.04057940691709518
# Epoch num 64/100
# Epoch train loss 0.02696246922843986
# Epoch validation loss 0.04074233323335648
# Epoch num 65/100
# Epoch train loss 0.026080009527504444
# Epoch validation loss 0.04299007430672645
# Epoch num 66/100
# Epoch train loss 0.025936096337520413
# Epoch validation loss 0.04446457140147686
# Epoch num 67/100
# Epoch train loss 0.025317917991843488
# Epoch validation loss 0.04602059572935104
# Epoch num 68/100
# Epoch train loss 0.02548698615282774
# Epoch validation loss 0.042849712818861005
# Epoch num 69/100
# Epoch train loss 0.02457951449064745
# Epoch validation loss 0.042825835198163985
# Epoch num 70/100
# Epoch train loss 0.023968654581242137
# Epoch validation loss 0.0439498707652092
# Epoch num 71/100
# Epoch train loss 0.025498072254574962
# Epoch validation loss 0.040489232540130614
# Epoch num 72/100
# Epoch train loss 0.024269575615310006
# Epoch validation loss 0.044009522348642346
# Epoch num 73/100
# Epoch train loss 0.024423378002312448
# Epoch validation loss 0.041842134296894075
# Epoch num 74/100
# Epoch train loss 0.024058481626626518
# Epoch validation loss 0.04451114684343338
# Epoch num 75/100
# Epoch train loss 0.023851264268159866
# Epoch validation loss 0.04791287109255791
# Epoch num 76/100
# Epoch train loss 0.023864444603936538
# Epoch validation loss 0.04198658838868141
# Epoch num 77/100
# Epoch train loss 0.023894340575983126
# Epoch validation loss 0.04190625101327896
# Epoch num 78/100
# Epoch train loss 0.021668160282489326
# Epoch validation loss 0.04816489331424236
# Epoch num 79/100
# Epoch train loss 0.02120320240242614
# Epoch validation loss 0.04064425304532051
# Epoch num 80/100
# Epoch train loss 0.022929141401416726
# Epoch validation loss 0.041293035447597506
# Epoch num 81/100
# Epoch train loss 0.022175843103064433
# Epoch validation loss 0.03985183760523796
# Epoch num 82/100
# Epoch train loss 0.01993531459528539
# Epoch validation loss 0.04234713315963745
# Epoch num 83/100
# Epoch train loss 0.019739977446281247
# Epoch validation loss 0.041198258846998216
# Epoch num 84/100
# Epoch train loss 0.019469589771082003
# Epoch validation loss 0.04667342901229858
# Epoch num 85/100
# Epoch train loss 0.01952777575287554
# Epoch validation loss 0.04219823703169823
# Epoch num 86/100
# Epoch train loss 0.01806408730852935
# Epoch validation loss 0.04177830517292023
# Epoch num 87/100
# Epoch train loss 0.017995708880739078
# Epoch validation loss 0.042039623484015465
# Epoch num 88/100
# Epoch train loss 0.018740539697723255
# Epoch validation loss 0.04122949540615082
# Epoch num 89/100
# Epoch train loss 0.01771836479504903
# Epoch validation loss 0.04352719224989414
# Epoch num 90/100
# Epoch train loss 0.01680075589360462
# Epoch validation loss 0.04540526196360588
# Epoch num 91/100
# Epoch train loss 0.015654244330815144
# Epoch validation loss 0.044022279977798465
# Epoch num 92/100
# Epoch train loss 0.01636759735022982
# Epoch validation loss 0.04450108036398888
# Epoch num 93/100
# Epoch train loss 0.015720348494748276
# Epoch validation loss 0.04569826275110245
# Epoch num 94/100
# Epoch train loss 0.014962516207661893
# Epoch validation loss 0.04866601377725601
# Epoch num 95/100
# Epoch train loss 0.014179459824744198
# Epoch validation loss 0.039209140837192534
# Epoch num 96/100
# Epoch train loss 0.013577820552099083
# Epoch validation loss 0.044985003769397736
# Epoch num 97/100
# Epoch train loss 0.014024630214812027
# Epoch validation loss 0.042818620800971985
# Epoch num 98/100
# Epoch train loss 0.012623202262653245
# Epoch validation loss 0.04575897008180618
# Epoch num 99/100
# Epoch train loss 0.012403417870195376
# Epoch validation loss 0.0423005748540163
# Epoch num 100/100
# Epoch train loss 0.0119489883331375
# Epoch validation loss 0.04553932696580887

# %%
scores = []
for path in test_paths:
    scores.append(float(score_dict[path].detach().cpu()))

# %%
result_df = pd.DataFrame({'path': test_paths, 'score': scores})
result_df.to_csv('/../../Results/sunetal-cnnimageretrieval-caltech101_700-p@100.csv',index=False)
