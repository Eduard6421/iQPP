# %%
import numpy as np
import pandas as pd

from collections import Counter
from scipy.stats import kendalltau
from sklearn.cluster import KMeans
from ast import literal_eval
import torch.nn as nn
from sklearn.neural_network import MLPClassifier
from scipy.stats import kurtosis
import pickle
from joblib import dump, load

# %%
query_embedding_df = pd.read_csv('../../Embeddings/CNN_Image_Retrieval/caltech101_700-query-features.csv')
db_embedding_df    = pd.read_csv('../../Embeddings/CNN_Image_Retrieval/caltech101_700-dataset-features.csv')

# %%
def get_embeddings(query_embeddings, dataset_embeddings):
     
    num_images   =  len(dataset_embeddings)
    num_queries  =  len(query_embeddings)
    
    print('Generating query embedding array')
    
    q_embeddings = []
    
    for query_id in range(num_queries):
        image_name = query_embeddings.iloc[query_id]['image_name']
        query_embedding = np.array(literal_eval(query_embeddings.iloc[query_id]['embedding']))
        q_embeddings.append(query_embedding)

    q_embeddings = np.array(q_embeddings)
    
    
    print('Generating dataset embedding_array')
    
    db_embeddings = []
    
    for item_id in range(num_images):
        if(item_id%1000 == 0):
            print(item_id)
        image_embedding = literal_eval(dataset_embeddings.iloc[item_id]['embedding'])
        db_embeddings.append(image_embedding)
    
    db_embeddings = np.array(db_embeddings)    
    
    return q_embeddings,db_embeddings

# %%
query_emb, db_emb = get_embeddings(query_embedding_df,db_embedding_df)
# Out:
# Generating query embedding array
# Generating dataset embedding_array
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000

# %%
clustering = KMeans(150)
clustering.fit(db_emb)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=150, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
x_train = db_emb
y_train = clustering.predict(db_emb)

# %%
clf = MLPClassifier(hidden_layer_sizes= (50,50),verbose=True, early_stopping=True,random_state=1).fit(x_train, y_train)
# Out:
# Iteration 1, loss = 4.96347620
# Validation score: 0.015385
# Iteration 2, loss = 4.66563335
# Validation score: 0.080473
# Iteration 3, loss = 4.06338962
# Validation score: 0.157396
# Iteration 4, loss = 3.36545771
# Validation score: 0.252071
# Iteration 5, loss = 2.78977111
# Validation score: 0.349112
# Iteration 6, loss = 2.34652025
# Validation score: 0.410651
# Iteration 7, loss = 2.01374255
# Validation score: 0.471006
# Iteration 8, loss = 1.75768572
# Validation score: 0.525444
# Iteration 9, loss = 1.55180047
# Validation score: 0.557396
# Iteration 10, loss = 1.39414542
# Validation score: 0.596450
# Iteration 11, loss = 1.26194248
# Validation score: 0.624852
# Iteration 12, loss = 1.15519062
# Validation score: 0.623669
# Iteration 13, loss = 1.05980249
# Validation score: 0.660355
# Iteration 14, loss = 0.98346797
# Validation score: 0.675740
# Iteration 15, loss = 0.91701052
# Validation score: 0.691124
# Iteration 16, loss = 0.85912351
# Validation score: 0.698225
# Iteration 17, loss = 0.80321332
# Validation score: 0.710059
# Iteration 18, loss = 0.76105755
# Validation score: 0.706509
# Iteration 19, loss = 0.71771601
# Validation score: 0.730178
# Iteration 20, loss = 0.68019153
# Validation score: 0.728994
# Iteration 21, loss = 0.65101715
# Validation score: 0.732544
# Iteration 22, loss = 0.62159160
# Validation score: 0.746746
# Iteration 23, loss = 0.59290663
# Validation score: 0.740828
# Iteration 24, loss = 0.56498864
# Validation score: 0.751479
# Iteration 25, loss = 0.54544455
# Validation score: 0.747929
# Iteration 26, loss = 0.51607544
# Validation score: 0.753846
# Iteration 27, loss = 0.49480645
# Validation score: 0.756213
# Iteration 28, loss = 0.47711501
# Validation score: 0.762130
# Iteration 29, loss = 0.46012228
# Validation score: 0.770414
# Iteration 30, loss = 0.44121323
# Validation score: 0.776331
# Iteration 31, loss = 0.42544687
# Validation score: 0.778698
# Iteration 32, loss = 0.41368325
# Validation score: 0.782249
# Iteration 33, loss = 0.39774294
# Validation score: 0.785799
# Iteration 34, loss = 0.38258167
# Validation score: 0.784615
# Iteration 35, loss = 0.37123560
# Validation score: 0.781065
# Iteration 36, loss = 0.35551653
# Validation score: 0.785799
# Iteration 37, loss = 0.34387022
# Validation score: 0.791716
# Iteration 38, loss = 0.33416812
# Validation score: 0.803550
# Iteration 39, loss = 0.32435857
# Validation score: 0.791716
# Iteration 40, loss = 0.30909367
# Validation score: 0.801183
# Iteration 41, loss = 0.30319066
# Validation score: 0.808284
# Iteration 42, loss = 0.29485988
# Validation score: 0.805917
# Iteration 43, loss = 0.28603244
# Validation score: 0.800000
# Iteration 44, loss = 0.27559929
# Validation score: 0.809467
# Iteration 45, loss = 0.26908124
# Validation score: 0.810651
# Iteration 46, loss = 0.25831159
# Validation score: 0.818935
# Iteration 47, loss = 0.25058331
# Validation score: 0.803550
# Iteration 48, loss = 0.24229084
# Validation score: 0.821302
# Iteration 49, loss = 0.23472981
# Validation score: 0.811834
# Iteration 50, loss = 0.22967852
# Validation score: 0.813018
# Iteration 51, loss = 0.22150984
# Validation score: 0.820118
# Iteration 52, loss = 0.21691544
# Validation score: 0.817751
# Iteration 53, loss = 0.20851396
# Validation score: 0.807101
# Iteration 54, loss = 0.20304973
# Validation score: 0.827219
# Iteration 55, loss = 0.19674882
# Validation score: 0.822485
# Iteration 56, loss = 0.19270619
# Validation score: 0.822485
# Iteration 57, loss = 0.18663532
# Validation score: 0.813018
# Iteration 58, loss = 0.17989461
# Validation score: 0.823669
# Iteration 59, loss = 0.17648556
# Validation score: 0.836686
# Iteration 60, loss = 0.17259011
# Validation score: 0.833136
# Iteration 61, loss = 0.16683090
# Validation score: 0.826036
# Iteration 62, loss = 0.16163438
# Validation score: 0.823669
# Iteration 63, loss = 0.15374409
# Validation score: 0.840237
# Iteration 64, loss = 0.15458283
# Validation score: 0.831953
# Iteration 65, loss = 0.14866631
# Validation score: 0.841420
# Iteration 66, loss = 0.14733375
# Validation score: 0.817751
# Iteration 67, loss = 0.13673463
# Validation score: 0.833136
# Iteration 68, loss = 0.13443090
# Validation score: 0.835503
# Iteration 69, loss = 0.13379771
# Validation score: 0.823669
# Iteration 70, loss = 0.13182360
# Validation score: 0.834320
# Iteration 71, loss = 0.12413976
# Validation score: 0.826036
# Iteration 72, loss = 0.11881454
# Validation score: 0.844970
# Iteration 73, loss = 0.11683372
# Validation score: 0.831953
# Iteration 74, loss = 0.11220091
# Validation score: 0.829586
# Iteration 75, loss = 0.10923155
# Validation score: 0.839053
# Iteration 76, loss = 0.10679052
# Validation score: 0.836686
# Iteration 77, loss = 0.10305526
# Validation score: 0.840237
# Iteration 78, loss = 0.09729514
# Validation score: 0.839053
# Iteration 79, loss = 0.09741428
# Validation score: 0.833136
# Iteration 80, loss = 0.09603611
# Validation score: 0.826036
# Iteration 81, loss = 0.09172017
# Validation score: 0.848521
# Iteration 82, loss = 0.08967420
# Validation score: 0.839053
# Iteration 83, loss = 0.08636007
# Validation score: 0.841420
# Iteration 84, loss = 0.08338571
# Validation score: 0.839053
# Iteration 85, loss = 0.08085878
# Validation score: 0.844970
# Iteration 86, loss = 0.07859836
# Validation score: 0.835503
# Iteration 87, loss = 0.07641438
# Validation score: 0.835503
# Iteration 88, loss = 0.07487475
# Validation score: 0.843787
# Iteration 89, loss = 0.07259170
# Validation score: 0.839053
# Iteration 90, loss = 0.06944512
# Validation score: 0.842604
# Iteration 91, loss = 0.06915087
# Validation score: 0.844970
# Iteration 92, loss = 0.06675963
# Validation score: 0.836686
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.

# %%
scores = []
for i in range(preds.shape[0]):
    score = kurtosis(preds[i])
    scores.append(score)
    
scores = np.array(scores)
result_df = pd.DataFrame({'path': np.array(query_embedding_df['image_name']), 'score': scores})
result_df.to_csv('../../Results/kurtosis-cnnimageretrieval-caltech101_700.csv',index=False)

# %%
scores = []
for i in range(preds.shape[0]):
    score = np.std(preds[i])
    scores.append(score)
    
scores = np.array(scores)
result_df = pd.DataFrame({'path': np.array(query_embedding_df['image_name']), 'score': scores})
result_df.to_csv('../../Results/head-deviation-cnnimageretrieval-caltech101_700.csv',index=False)
